# %%
import pandas as pd
import os

# Define the folder path for New York electricity prices
newyork_price_folder = '/Users/aashrithasankineni/Downloads/newyork_electricity_prices'

# Initialize a list to hold each file's data
newyork_price_dfs = []

# Load each CSV file in the newyork_electricity_prices folder
if os.path.exists(newyork_price_folder):
    for filename in os.listdir(newyork_price_folder):
        if filename.endswith('.csv'):
            file_path = os.path.join(newyork_price_folder, filename)
            newyork_price_dfs.append(pd.read_csv(file_path, delimiter=',', on_bad_lines='skip'))
            print(f"Loaded data from {filename}")
else:
    print(f"Folder not found: {newyork_price_folder}")

# Concatenate all dataframes if any files were loaded
if newyork_price_dfs:
    newyork_price_df = pd.concat(newyork_price_dfs, ignore_index=True)
    print("Combined New York Electricity Prices Data:\n", newyork_price_df.head())
else:
    print("No New York electricity prices data loaded.")
# Out:
# Loaded data from nyiso_lmp_rt_5min_zones_2022Q4.csv
# Loaded data from nyiso_lmp_rt_5min_zones_2024Q2.csv
# Loaded data from nyiso_lmp_rt_5min_zones_2024Q3.csv
# Loaded data from forecasted_electricity_prices_2025.csv
# Loaded data from nyiso_lmp_rt_5min_zones_2024Q1.csv
# Loaded data from nyiso_lmp_rt_5min_zones_2022Q2.csv
# Loaded data from nyiso_lmp_rt_5min_zones_2024Q4.csv
# Loaded data from nyiso_lmp_rt_5min_zones_2022Q3.csv
# Loaded data from nyiso_lmp_rt_5min_zones_2022Q1.csv
# Loaded data from nyiso_lmp_rt_5min_zones_2023Q4.csv
# Loaded data from nyiso_lmp_rt_5min_zones_2023Q1.csv
# Loaded data from nyiso_lmp_rt_5min_zones_2023Q2.csv
# Loaded data from nyiso_lmp_rt_5min_zones_2023Q3.csv
# Loaded data from forecasted_electricity_prices_2025_sarima.csv
# Loaded data from forecasted_electricity_prices_2025_daily.csv
# Loaded data from forecasted_electricity_prices_2025_monthly.csv
# Combined New York Electricity Prices Data:
# ...

# %%
import pandas as pd
import os

# Define the base folder path directly to the Downloads directory
newyork_carbon_folder = '/Users/aashrithasankineni/Downloads'

# Specific folder name for New York carbon footprint within Downloads
newyork_carbon_subfolder = 'newyork_carbon_footprint'
newyork_carbon_full_path = os.path.join(newyork_carbon_folder, newyork_carbon_subfolder)

# Initialize a list to hold each file's data
newyork_carbon_dfs = []

# Load each CSV file in the newyork_carbon_footprint folder
if os.path.exists(newyork_carbon_full_path):
    for filename in os.listdir(newyork_carbon_full_path):
        if filename.endswith('.csv'):
            file_path = os.path.join(newyork_carbon_full_path, filename)
            newyork_carbon_dfs.append(pd.read_csv(file_path, delimiter=',', on_bad_lines='skip'))
            print(f"Loaded data from {filename}")
else:
    print(f"Folder not found: {newyork_carbon_full_path}")

# Concatenate all dataframes if any files were loaded
if newyork_carbon_dfs:
    newyork_carbon_df = pd.concat(newyork_carbon_dfs, ignore_index=True)
    print("Combined New York Carbon Footprint Data:\n", newyork_carbon_df.head())
else:
    print("No New York carbon footprint data loaded.")
# Out:
# Loaded data from US-NY-NYIS_2021_hourly.csv
# Loaded data from US-NY-NYIS_2023_hourly.csv
# Loaded data from forecast_2024_hourly_sarima.csv
# Loaded data from US-NY-NYIS_2022_hourly.csv
# Combined New York Carbon Footprint Data:
#          Datetime (UTC) Country                             Zone Name  \
# 0  2021-01-01 00:00:00     USA  New York Independent System Operator
# 1  2021-01-01 01:00:00     USA  New York Independent System Operator
# 2  2021-01-01 02:00:00     USA  New York Independent System Operator
# 3  2021-01-01 03:00:00     USA  New York Independent System Operator
# 4  2021-01-01 04:00:00     USA  New York Independent System Operator
#
#       Zone Id  Carbon Intensity gCO₂eq/kWh (direct)  \
# 0  US-NY-NYIS                                189.97
# 1  US-NY-NYIS                                184.54
# 2  US-NY-NYIS                                177.86
# 3  US-NY-NYIS                                163.35
# 4  US-NY-NYIS                                158.12
#
# ...

# %%
import pandas as pd
import os

# Define the folder path for California carbon footprint data
california_carbon_folder = '/Users/aashrithasankineni/Downloads/california_carbon_footprint'

# Initialize a list to hold each file's data
california_carbon_dfs = []

# Load each CSV file in the california_carbon_footprint folder
if os.path.exists(california_carbon_folder):
    for filename in os.listdir(california_carbon_folder):
        if filename.endswith('.csv'):
            file_path = os.path.join(california_carbon_folder, filename)
            california_carbon_dfs.append(pd.read_csv(file_path, delimiter=',', on_bad_lines='skip'))
            print(f"Loaded data from {filename}")
else:
    print(f"Folder not found: {california_carbon_folder}")

# Concatenate all dataframes if any files were loaded
if california_carbon_dfs:
    california_carbon_df = pd.concat(california_carbon_dfs, ignore_index=True)
    print("Combined California Carbon Footprint Data:\n", california_carbon_df.head())
else:
    print("No California carbon footprint data loaded.")
# Out:
# Loaded data from US-CAL-CISO_2022_hourly.csv
# Loaded data from US-CAL-CISO_2023_hourly.csv
# Loaded data from US-CAL-CISO_2021_hourly.csv
# Combined California Carbon Footprint Data:
#          Datetime (UTC) Country                               Zone Name  \
# 0  2022-01-01 00:00:00     USA  California Independent System Operator
# 1  2022-01-01 01:00:00     USA  California Independent System Operator
# 2  2022-01-01 02:00:00     USA  California Independent System Operator
# 3  2022-01-01 03:00:00     USA  California Independent System Operator
# 4  2022-01-01 04:00:00     USA  California Independent System Operator
#
#        Zone Id  Carbon Intensity gCO₂eq/kWh (direct)  \
# 0  US-CAL-CISO                                209.26
# 1  US-CAL-CISO                                225.02
# 2  US-CAL-CISO                                228.91
# 3  US-CAL-CISO                                231.82
# 4  US-CAL-CISO                                235.79
#
# ...

# %%
import pandas as pd
import os

# Define the folder path for California electricity prices data
california_price_folder = '/Users/aashrithasankineni/Downloads/california_electricity_prices'

# Initialize a list to hold each file's data
california_price_dfs = []

# Load each CSV file in the california_electricity_prices folder
if os.path.exists(california_price_folder):
    for filename in os.listdir(california_price_folder):
        if filename.endswith('.csv'):
            file_path = os.path.join(california_price_folder, filename)
            california_price_dfs.append(pd.read_csv(file_path, delimiter=',', on_bad_lines='skip'))
            print(f"Loaded data from {filename}")
else:
    print(f"Folder not found: {california_price_folder}")

# Concatenate all dataframes if any files were loaded
if california_price_dfs:
    california_price_df = pd.concat(california_price_dfs, ignore_index=True)
    print("Combined California Electricity Prices Data:\n", california_price_df.head())
else:
    print("No California electricity prices data loaded.")
# Out:
# Loaded data from forecasted_electricity_prices_2025.csv
# Loaded data from forecast_2024.csv
# Loaded data from optimized_forecasted_electricity_prices_2025.csv
# Loaded data from caiso_lmp_rt_5min_interfaces_2022Q1.csv
# Loaded data from caiso_lmp_rt_5min_interfaces_2022Q3.csv
# Loaded data from caiso_lmp_rt_5min_interfaces_2022Q2.csv
# Loaded data from caiso_lmp_rt_5min_interfaces_2024Q4.csv
# Loaded data from forecasted_electricity_prices_2025_sarima.csv
# Loaded data from caiso_lmp_rt_5min_interfaces_2024Q1.csv
# Loaded data from forecasted_electricity_prices_2025_daily.csv
# Loaded data from forecasted_electricity_prices_2025_monthly.csv
# Loaded data from caiso_lmp_rt_5min_interfaces_2024Q3.csv
# Loaded data from caiso_lmp_rt_5min_interfaces_2022Q4.csv
# Loaded data from caiso_lmp_rt_5min_interfaces_2024Q2.csv
# Loaded data from caiso_lmp_rt_5min_interfaces_2023Q3.csv
# Loaded data from caiso_lmp_rt_5min_interfaces_2021Q1.csv
# ...

# %%
import pandas as pd
import os

# Define the folder path for Texas electricity prices data
texas_price_folder = '/Users/aashrithasankineni/Downloads/texas_electricity_prices'

# Initialize a list to hold each file's data
texas_price_dfs = []

# Load each CSV file in the texas_electricity_prices folder
if os.path.exists(texas_price_folder):
    for filename in os.listdir(texas_price_folder):
        if filename.endswith('.csv'):
            file_path = os.path.join(texas_price_folder, filename)
            texas_price_dfs.append(pd.read_csv(file_path, delimiter=',', on_bad_lines='skip'))
            print(f"Loaded data from {filename}")
else:
    print(f"Folder not found: {texas_price_folder}")

# Concatenate all dataframes if any files were loaded
if texas_price_dfs:
    texas_price_df = pd.concat(texas_price_dfs, ignore_index=True)
    print("Combined Texas Electricity Prices Data:\n", texas_price_df.head())
else:
    print("No Texas electricity prices data loaded.")
# Out:
# Loaded data from ercot_lmp_rt_15min_hubs_2021Q1.csv
# Loaded data from ercot_lmp_rt_15min_hubs_2023Q3.csv
# Loaded data from ercot_lmp_rt_15min_hubs_2023Q2.csv
# Loaded data from ercot_lmp_rt_15min_hubs_2021Q2.csv
# Loaded data from ercot_lmp_rt_15min_hubs_2023Q1.csv
# Loaded data from ercot_lmp_rt_15min_hubs_2021Q3.csv
# Loaded data from ercot_lmp_rt_15min_hubs_2023Q4.csv
# Loaded data from ercot_lmp_rt_15min_hubs_2021Q4.csv
# Loaded data from ercot_lmp_rt_15min_hubs_2020Q2.csv
# Loaded data from ercot_lmp_rt_15min_hubs_2020Q3.csv
# Loaded data from ercot_lmp_rt_15min_hubs_2022Q1.csv
# Loaded data from ercot_lmp_rt_15min_hubs_2022Q3.csv
# Loaded data from ercot_lmp_rt_15min_hubs_2020Q1.csv
# Loaded data from ercot_lmp_rt_15min_hubs_2024Q4.csv
# Loaded data from ercot_lmp_rt_15min_hubs_2022Q2.csv
# Loaded data from ercot_lmp_rt_15min_hubs_2020Q4.csv
# Loaded data from ercot_lmp_rt_15min_hubs_2024Q1.csv
# Loaded data from ercot_lmp_rt_15min_hubs_2024Q3.csv
# ...

# %%
import os
import pandas as pd
from statsmodels.tsa.stattools import adfuller

# Paths to the data folders
data_paths = {
    'california_electricity_prices': '/Users/aashrithasankineni/Downloads/california_electricity_prices',
    'california_carbon_footprint': '/Users/aashrithasankineni/Downloads/california_carbon_footprint',
    'texas_electricity_prices': '/Users/aashrithasankineni/Downloads/texas_electricity_prices',
    'texas_carbon_footprint': '/Users/aashrithasankineni/Downloads/texas_carbon_footprint',
    'newyork_electricity_prices': '/Users/aashrithasankineni/Downloads/newyork_electricity_prices',
    'newyork_carbon_footprint': '/Users/aashrithasankineni/Downloads/newyork_carbon_footprint'
}

# Configuration for electricity files based on sample files inspected
electricity_config = {
    "california_electricity_prices": {"skip_rows": 3, "datetime_col": "UTC Timestamp (Interval Ending)", "price_col": "PALOVRDE_ASR-APND LMP"},
    "texas_electricity_prices": {"skip_rows": 3, "datetime_col": "UTC Timestamp (Interval Ending)", "price_col": "Hub average LMP"},
    "newyork_electricity_prices": {"skip_rows": 3, "datetime_col": "UTC Timestamp (Interval Ending)", "price_col": "A - West LMP"}
}

# Dictionary to store ARIMA-prepared dataframes
arima_ready_data = {}

# ARIMA-specific preprocessing function
def preprocess_for_arima(df, target_column):
    # Convert datetime column to datetime format
    df['datetime'] = pd.to_datetime(df['datetime'], errors='coerce')
    df.set_index('datetime', inplace=True)
    
    # Ensure target column data is numeric and handle missing values
    df[target_column] = pd.to_numeric(df[target_column], errors='coerce')
    df[target_column] = df[target_column].interpolate(method='linear').ffill().bfill()
    
    # Check stationarity with ADF test; apply differencing if needed
    result = adfuller(df[target_column].dropna())
    if result[1] > 0.05:  # p-value > 0.05 suggests non-stationarity
        df[target_column] = df[target_column].diff().dropna()
    
    return df

# Process each dataset for ARIMA preprocessing
for folder_name, folder_path in data_paths.items():
    # Determine whether it's an electricity price or carbon footprint folder
    is_electricity = 'electricity' in folder_name
    target_column = 'marginal_price' if is_electricity else 'carbon_intensity'
    
    # Loop through each file in the folder
    for filename in os.listdir(folder_path):
        file_path = os.path.join(folder_path, filename)
        
        # Process only .csv files
        if filename.endswith('.csv'):
            try:
                # Handle electricity files with specific configurations
                if is_electricity:
                    config = electricity_config.get(folder_name, None)
                    if config:
                        # Load file, skipping metadata rows
                        df = pd.read_csv(file_path, skiprows=config["skip_rows"])
                        
                        # Check if required columns are present
                        if config["datetime_col"] in df.columns and config["price_col"] in df.columns:
                            df = df[[config["datetime_col"], config["price_col"]]]
                            df.columns = ['datetime', target_column]
                        else:
                            print(f"Skipping {filename} due to missing columns.")
                            continue
                    else:
                        print(f"No configuration for {folder_name}. Skipping file.")
                        continue

                # Handle carbon footprint files (assumes datetime in 1st column, carbon intensity in 6th column if no headers)
                else:
                    df = pd.read_csv(file_path, on_bad_lines='skip')
                    if 'datetime' in df.columns and 'carbon_intensity' in df.columns:
                        df = df[['datetime', 'carbon_intensity']]
                    elif df.shape[1] > 5:
                        df = df.iloc[:, [0, 5]]
                        df.columns = ['datetime', target_column]
                    else:
                        print(f"Skipping {filename} due to insufficient columns.")
                        continue
                
                # Preprocess data for ARIMA
                processed_df = preprocess_for_arima(df, target_column)
                if processed_df is not None:
                    arima_ready_data[file_path] = processed_df
                    print(f"ARIMA preprocessing completed for {file_path}")
            except Exception as e:
                print(f"Error processing {file_path}: {e}")

# Display processed data
for name, df in arima_ready_data.items():
    print(f"\nProcessed data for ARIMA in {name}:\n", df.head())
# Out:
# Skipping forecasted_electricity_prices_2025.csv due to missing columns.
# Skipping forecast_2024.csv due to missing columns.
# Skipping optimized_forecasted_electricity_prices_2025.csv due to missing columns.
# ARIMA preprocessing completed for /Users/aashrithasankineni/Downloads/california_electricity_prices/caiso_lmp_rt_5min_interfaces_2022Q1.csv
# ARIMA preprocessing completed for /Users/aashrithasankineni/Downloads/california_electricity_prices/caiso_lmp_rt_5min_interfaces_2022Q3.csv
# ARIMA preprocessing completed for /Users/aashrithasankineni/Downloads/california_electricity_prices/caiso_lmp_rt_5min_interfaces_2022Q2.csv
# ARIMA preprocessing completed for /Users/aashrithasankineni/Downloads/california_electricity_prices/caiso_lmp_rt_5min_interfaces_2024Q4.csv
# Skipping forecasted_electricity_prices_2025_sarima.csv due to missing columns.
# ...

# %%
import os
import pandas as pd

# Path to the New York electricity prices folder
ny_folder_path = '/Users/aashrithasankineni/Downloads/newyork_electricity_prices'

# List columns for each file in the folder
for filename in os.listdir(ny_folder_path):
    file_path = os.path.join(ny_folder_path, filename)
    
    # Process only .csv files
    if filename.endswith('.csv'):
        try:
            # Read only the first few rows to inspect column names
            df = pd.read_csv(file_path, skiprows=3, nrows=5)
            print(f"\n{filename} columns:\n{df.columns.tolist()}")
        except Exception as e:
            print(f"Error reading columns in {filename}: {e}")
# Out:
# nyiso_lmp_rt_5min_zones_2022Q4.csv columns:
# ...

# %%
import os
import pandas as pd
from statsmodels.tsa.stattools import adfuller

# Path to the New York electricity prices folder
ny_folder_path = '/Users/aashrithasankineni/Downloads/newyork_electricity_prices'

# Dictionary to store ARIMA-prepared dataframes
arima_ready_data = {}

# ARIMA-specific preprocessing function
def preprocess_for_arima(df, target_column):
    df['datetime'] = pd.to_datetime(df['datetime'], errors='coerce')
    df.set_index('datetime', inplace=True)
    
    df[target_column] = pd.to_numeric(df[target_column], errors='coerce')
    df[target_column] = df[target_column].interpolate(method='linear').ffill().bfill()
    
    result = adfuller(df[target_column].dropna())
    if result[1] > 0.05:
        df[target_column] = df[target_column].diff().dropna()
    
    return df

# Process each New York file for ARIMA with flexible column handling
for filename in os.listdir(ny_folder_path):
    file_path = os.path.join(ny_folder_path, filename)
    
    # Process only .csv files
    if filename.endswith('.csv'):
        try:
            # Load file and inspect columns
            df = pd.read_csv(file_path, skiprows=3)
            
            # Check for 'UTC Timestamp (Interval Ending)' as datetime
            datetime_col = 'UTC Timestamp (Interval Ending)'
            
            # Dynamically identify an LMP column if 'A - West LMP' is not available
            lmp_columns = [col for col in df.columns if 'LMP' in col]
            
            if datetime_col in df.columns and lmp_columns:
                # Use the first available LMP column
                selected_lmp_col = lmp_columns[0]
                df = df[[datetime_col, selected_lmp_col]]
                df.columns = ['datetime', 'marginal_price']
                
                # Preprocess the data for ARIMA
                processed_df = preprocess_for_arima(df, 'marginal_price')
                arima_ready_data[file_path] = processed_df
                print(f"ARIMA preprocessing completed for {filename} using '{selected_lmp_col}'")
            else:
                print(f"Skipping {filename} due to missing required columns.")
                print(f"Available columns in {filename}: {df.columns.tolist()}")
        except Exception as e:
            print(f"Error processing {filename}: {e}")

# Display processed data for verification
for name, df in arima_ready_data.items():
    print(f"\nProcessed data for ARIMA in {name}:\n", df.head())
# Out:
# ARIMA preprocessing completed for nyiso_lmp_rt_5min_zones_2022Q4.csv using 'A - West LMP'
# ARIMA preprocessing completed for nyiso_lmp_rt_5min_zones_2024Q2.csv using 'A - West LMP'
# ARIMA preprocessing completed for nyiso_lmp_rt_5min_zones_2024Q3.csv using 'A - West LMP'
# ARIMA preprocessing completed for nyiso_lmp_rt_5min_zones_2024Q1.csv using 'A - West LMP'
# ARIMA preprocessing completed for nyiso_lmp_rt_5min_zones_2022Q2.csv using 'A - West LMP'
# ARIMA preprocessing completed for nyiso_lmp_rt_5min_zones_2024Q4.csv using 'A - West LMP'
# ARIMA preprocessing completed for nyiso_lmp_rt_5min_zones_2022Q3.csv using 'A - West LMP'
# ARIMA preprocessing completed for nyiso_lmp_rt_5min_zones_2022Q1.csv using 'A - West LMP'
# ARIMA preprocessing completed for nyiso_lmp_rt_5min_zones_2023Q4.csv using 'A - West LMP'
# ARIMA preprocessing completed for nyiso_lmp_rt_5min_zones_2023Q1.csv using 'A - West LMP'
# ...

# %%
import os
import pandas as pd

# Base folder paths
base_folders = {
    "california": "/Users/aashrithasankineni/Downloads/california_carbon_footprint",
    "newyork": "/Users/aashrithasankineni/Downloads/newyork_carbon_footprint",
    "texas": "/Users/aashrithasankineni/Downloads/texas_carbon_footprint",
}

# Helper function to load files from a folder
def load_files_from_folder(folder_path):
    return [os.path.join(folder_path, file) for file in os.listdir(folder_path) if file.endswith(".csv")]

# Helper function to load, clean, and resample data
def process_carbon_files(files, time_col="Datetime (UTC)", freq="H"):
    combined_df = []
    for file in files:
        try:
            print(f"Processing file: {file}")
            df = pd.read_csv(file)
            
            if df.empty:
                print(f"Warning: {file} is empty.")
                continue
            
            # Ensure the timestamp column is properly parsed
            if time_col not in df.columns:
                print(f"Error: {time_col} not found in {file}. Available columns: {df.columns}")
                continue
            df[time_col] = pd.to_datetime(df[time_col], errors="coerce")
            df.set_index(time_col, inplace=True)
            
            # Filter numeric columns only
            numeric_df = df.select_dtypes(include=["number"])
            if numeric_df.empty:
                print(f"Warning: No numeric columns found in {file}. Skipping.")
                continue
            
            # Resample to hourly frequency
            numeric_df = numeric_df.resample(freq).mean()
            combined_df.append(numeric_df)
        
        except Exception as e:
            print(f"Error processing file {file}: {e}")
    
    if not combined_df:
        raise ValueError("No valid data found in the provided files.")
    
    return pd.concat(combined_df)

# Load and process carbon footprint data for California, New York, and Texas
try:
    california_files = load_files_from_folder(base_folders["california"])
    california_carbon = process_carbon_files(california_files)
    print("California carbon data processed successfully.")
except ValueError as ve:
    print(f"Critical Error (California): {ve}")

try:
    newyork_files = load_files_from_folder(base_folders["newyork"])
    newyork_carbon = process_carbon_files(newyork_files)
    print("New York carbon data processed successfully.")
except ValueError as ve:
    print(f"Critical Error (New York): {ve}")

try:
    texas_files = load_files_from_folder(base_folders["texas"])
    texas_carbon = process_carbon_files(texas_files)
    print("Texas carbon data processed successfully.")
except ValueError as ve:
    print(f"Critical Error (Texas): {ve}")
# Out:
# Processing file: /Users/aashrithasankineni/Downloads/california_carbon_footprint/US-CAL-CISO_2022_hourly.csv
# Processing file: /Users/aashrithasankineni/Downloads/california_carbon_footprint/US-CAL-CISO_2023_hourly.csv
# Processing file: /Users/aashrithasankineni/Downloads/california_carbon_footprint/US-CAL-CISO_2021_hourly.csv
# California carbon data processed successfully.
# Processing file: /Users/aashrithasankineni/Downloads/newyork_carbon_footprint/US-NY-NYIS_2021_hourly.csv
# Processing file: /Users/aashrithasankineni/Downloads/newyork_carbon_footprint/US-NY-NYIS_2023_hourly.csv
# Processing file: /Users/aashrithasankineni/Downloads/newyork_carbon_footprint/US-NY-NYIS_2022_hourly.csv
# New York carbon data processed successfully.
# Processing file: /Users/aashrithasankineni/Downloads/texas_carbon_footprint/US-TEX-ERCO_2023_hourly.csv
# Processing file: /Users/aashrithasankineni/Downloads/texas_carbon_footprint/US-TEX-ERCO_2021_hourly.csv
# ...

# %%
import os
import pandas as pd

# Define folder paths for electricity prices
price_folders = {
    "california": "/Users/aashrithasankineni/Downloads/california_electricity_prices",
    "newyork": "/Users/aashrithasankineni/Downloads/newyork_electricity_prices",
    "texas": "/Users/aashrithasankineni/Downloads/texas_electricity_prices",
}

# Helper function to load files from a folder
def load_files_from_folder(folder_path):
    return [os.path.join(folder_path, file) for file in os.listdir(folder_path) if file.endswith(".csv")]

# Helper function to load, clean, and resample data
def process_price_files(files, time_col="UTC Timestamp (Interval Ending)", freq="H"):
    combined_df = []
    for file in files:
        try:
            print(f"Processing file: {file}")
            # Skip metadata rows (adjust `skiprows` as needed based on file inspection)
            df = pd.read_csv(file, skiprows=3)  
            
            if df.empty:
                print(f"Warning: {file} is empty.")
                continue
            
            # Ensure the timestamp column is properly parsed
            if time_col not in df.columns:
                print(f"Error: {time_col} not found in {file}. Available columns: {df.columns}")
                continue
            df[time_col] = pd.to_datetime(df[time_col], errors="coerce")
            df.set_index(time_col, inplace=True)
            
            # Filter numeric columns only
            numeric_df = df.select_dtypes(include=["number"])
            if numeric_df.empty:
                print(f"Warning: No numeric columns found in {file}. Skipping.")
                continue
            
            # Resample to hourly frequency
            numeric_df = numeric_df.resample(freq).mean()
            combined_df.append(numeric_df)
        
        except Exception as e:
            print(f"Error processing file {file}: {e}")
    
    if not combined_df:
        raise ValueError("No valid data found in the provided files.")
    
    return pd.concat(combined_df)

# Load and process electricity price data for California, New York, and Texas
try:
    california_files = load_files_from_folder(price_folders["california"])
    california_prices = process_price_files(california_files)
    print("California electricity price data processed successfully.")
except ValueError as ve:
    print(f"Critical Error (California Prices): {ve}")

try:
    newyork_files = load_files_from_folder(price_folders["newyork"])
    newyork_prices = process_price_files(newyork_files)
    print("New York electricity price data processed successfully.")
except ValueError as ve:
    print(f"Critical Error (New York Prices): {ve}")

try:
    texas_files = load_files_from_folder(price_folders["texas"])
    texas_prices = process_price_files(texas_files)
    print("Texas electricity price data processed successfully.")
except ValueError as ve:
    print(f"Critical Error (Texas Prices): {ve}")
# Out:
# Processing file: /Users/aashrithasankineni/Downloads/california_electricity_prices/caiso_lmp_rt_5min_interfaces_2022Q1.csv
# Processing file: /Users/aashrithasankineni/Downloads/california_electricity_prices/caiso_lmp_rt_5min_interfaces_2022Q3.csv
# Processing file: /Users/aashrithasankineni/Downloads/california_electricity_prices/caiso_lmp_rt_5min_interfaces_2022Q2.csv
# Processing file: /Users/aashrithasankineni/Downloads/california_electricity_prices/caiso_lmp_rt_5min_interfaces_2024Q4.csv
# Processing file: /Users/aashrithasankineni/Downloads/california_electricity_prices/caiso_lmp_rt_5min_interfaces_2024Q1.csv
# Processing file: /Users/aashrithasankineni/Downloads/california_electricity_prices/caiso_lmp_rt_5min_interfaces_2024Q3.csv
# Processing file: /Users/aashrithasankineni/Downloads/california_electricity_prices/caiso_lmp_rt_5min_interfaces_2022Q4.csv
# Processing file: /Users/aashrithasankineni/Downloads/california_electricity_prices/caiso_lmp_rt_5min_interfaces_2024Q2.csv
# ...

# %%
# Align carbon footprint and electricity price datasets by timestamp
def align_datasets(carbon_data, price_data):
    aligned_carbon, aligned_prices = carbon_data.align(price_data, join="inner", axis=0)
    return aligned_carbon, aligned_prices

# Align datasets for California
california_carbon_aligned, california_prices_aligned = align_datasets(california_carbon, california_prices)

# Align datasets for New York
newyork_carbon_aligned, newyork_prices_aligned = align_datasets(newyork_carbon, newyork_prices)

# Align datasets for Texas
texas_carbon_aligned, texas_prices_aligned = align_datasets(texas_carbon, texas_prices)

print("Datasets aligned successfully.")
# Out:
# Datasets aligned successfully.

# %%
# Function to inspect the raw structure of a file
def inspect_file_structure(file_path, num_lines=10):
    try:
        with open(file_path, "r") as f:
            lines = [f.readline().strip() for _ in range(num_lines)]
        print(f"First {num_lines} lines of {file_path}:")
        for i, line in enumerate(lines):
            print(f"Line {i + 1}: {line}")
    except Exception as e:
        print(f"Error reading {file_path}: {e}")

# Inspect raw file structure
california_price_sample = "/Users/aashrithasankineni/Downloads/california_electricity_prices/caiso_lmp_rt_5min_interfaces_2022Q1.csv"
newyork_price_sample = "/Users/aashrithasankineni/Downloads/newyork_electricity_prices/nyiso_lmp_rt_5min_zones_2022Q1.csv"
texas_price_sample = "/Users/aashrithasankineni/Downloads/texas_electricity_prices/ercot_lmp_rt_15min_hubs_2022Q1.csv"

inspect_file_structure(california_price_sample)
inspect_file_structure(newyork_price_sample)
inspect_file_structure(texas_price_sample)
# Out:
# First 10 lines of /Users/aashrithasankineni/Downloads/california_electricity_prices/caiso_lmp_rt_5min_interfaces_2022Q1.csv:
# Line 1: CAISO 5-Minute Real-Time Locational Marginal Prices ($/megawatt) for Interfaces
# Line 2: 5-minute real-time locational marginal prices for CAISO
# Line 3: Source: EIA collected from CAISO
# ...

# %%
import pandas as pd
import os

def detect_header(file_path, keyword="UTC Timestamp"):
    """
    Detect the header row dynamically by looking for a keyword in the file.
    """
    with open(file_path, 'r') as file:
        for i, line in enumerate(file):
            if keyword in line:
                return i
    return None  # Return None if the keyword is not found

def process_price_files_dynamic(files, time_col="UTC Timestamp (Interval Ending)", freq="H"):
    combined_df = []
    for file in files:
        try:
            print(f"Processing file: {file}")
            
            # Detect the header row dynamically
            header_row = detect_header(file, keyword="UTC Timestamp")
            if header_row is None:
                print(f"Error: Unable to detect header in {file}. Skipping.")
                continue
            
            # Read the file with the detected header
            df = pd.read_csv(file, skiprows=header_row)
            
            # Ensure the timestamp column exists
            if time_col not in df.columns:
                print(f"Error: {time_col} not found in {file}. Columns: {df.columns}")
                continue

            # Parse timestamps and set index
            df[time_col] = pd.to_datetime(df[time_col], errors="coerce")
            df.set_index(time_col, inplace=True)
            
            # Select LMP columns (columns containing "LMP")
            lmp_columns = [col for col in df.columns if "LMP" in col]
            if not lmp_columns:
                print(f"Warning: No LMP columns found in {file}. Skipping.")
                continue

            # Aggregate LMP columns (mean of all LMP columns)
            df["Average LMP"] = df[lmp_columns].mean(axis=1)
            
            # Resample to hourly frequency
            hourly_df = df["Average LMP"].resample(freq).mean()
            combined_df.append(hourly_df)
        
        except Exception as e:
            print(f"Error processing file {file}: {e}")
    
    if not combined_df:
        raise ValueError("No valid data found in the provided files.")
    
    return pd.concat(combined_df)

# Define paths to electricity price folders
price_folders = {
    "california": "/Users/aashrithasankineni/Downloads/california_electricity_prices",
    "newyork": "/Users/aashrithasankineni/Downloads/newyork_electricity_prices",
    "texas": "/Users/aashrithasankineni/Downloads/texas_electricity_prices",
}

# Load files from folders
def load_files_from_folder(folder_path):
    return [os.path.join(folder_path, file) for file in os.listdir(folder_path) if file.endswith(".csv")]

# Process files for each region
try:
    california_files = load_files_from_folder(price_folders["california"])
    california_prices = process_price_files_dynamic(california_files)
    print("California electricity price data processed successfully.")
except ValueError as ve:
    print(f"Critical Error (California Prices): {ve}")

try:
    newyork_files = load_files_from_folder(price_folders["newyork"])
    newyork_prices = process_price_files_dynamic(newyork_files)
    print("New York electricity price data processed successfully.")
except ValueError as ve:
    print(f"Critical Error (New York Prices): {ve}")

try:
    texas_files = load_files_from_folder(price_folders["texas"])
    texas_prices = process_price_files_dynamic(texas_files)
    print("Texas electricity price data processed successfully.")
except ValueError as ve:
    print(f"Critical Error (Texas Prices): {ve}")
# Out:
# Processing file: /Users/aashrithasankineni/Downloads/california_electricity_prices/caiso_lmp_rt_5min_interfaces_2022Q1.csv
# Processing file: /Users/aashrithasankineni/Downloads/california_electricity_prices/caiso_lmp_rt_5min_interfaces_2022Q3.csv
# Processing file: /Users/aashrithasankineni/Downloads/california_electricity_prices/caiso_lmp_rt_5min_interfaces_2022Q2.csv
# Processing file: /Users/aashrithasankineni/Downloads/california_electricity_prices/caiso_lmp_rt_5min_interfaces_2024Q4.csv
# Processing file: /Users/aashrithasankineni/Downloads/california_electricity_prices/caiso_lmp_rt_5min_interfaces_2024Q1.csv
# Processing file: /Users/aashrithasankineni/Downloads/california_electricity_prices/caiso_lmp_rt_5min_interfaces_2024Q3.csv
# Processing file: /Users/aashrithasankineni/Downloads/california_electricity_prices/caiso_lmp_rt_5min_interfaces_2022Q4.csv
# Processing file: /Users/aashrithasankineni/Downloads/california_electricity_prices/caiso_lmp_rt_5min_interfaces_2024Q2.csv
# ...

# %%
pip install scikit-learn
# Out:
# ...
#   Using cached scikit_learn-1.5.2-cp313-cp313-macosx_12_0_arm64.whl.metadata (13 kB)
# ...
#   Using cached joblib-1.4.2-py3-none-any.whl.metadata (5.4 kB)
# ...
#   Using cached threadpoolctl-3.5.0-py3-none-any.whl.metadata (13 kB)
# Using cached scikit_learn-1.5.2-cp313-cp313-macosx_12_0_arm64.whl (11.0 MB)
# Using cached joblib-1.4.2-py3-none-any.whl (301 kB)
# Using cached threadpoolctl-3.5.0-py3-none-any.whl (18 kB)
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
print(forecast_mean.head(10))  # Check the first 10 forecasted values
print(forecast_mean.describe())  # Check variance and mean
# Out:
# 2025-01-01 00:00:00   -0.010312
# 2025-01-01 01:00:00   -0.010312
# 2025-01-01 02:00:00   -0.010312
# 2025-01-01 03:00:00   -0.010312
# 2025-01-01 04:00:00   -0.010312
# 2025-01-01 05:00:00   -0.010312
# 2025-01-01 06:00:00   -0.010312
# 2025-01-01 07:00:00   -0.010312
# 2025-01-01 08:00:00   -0.010312
# 2025-01-01 09:00:00   -0.010312
# Freq: h, Name: predicted_mean, dtype: float64
# count    8.760000e+03
# mean    -1.031231e-02
# std      3.469645e-18
# min     -1.031231e-02
# 25%     -1.031231e-02
# 50%     -1.031231e-02
# 75%     -1.031231e-02
# max     -1.031231e-02
# Name: predicted_mean, dtype: float64

# %%
# Reloading datasets with chunk processing to handle memory issues
datasets = []
for file_path in file_paths:
    data = load_file_in_chunks(file_path, datetime_col, target_col)
    if data is not None:
        datasets.append(data)

# Combine datasets
if datasets:
    combined_data = pd.concat(datasets).sort_index()
    combined_data = combined_data[~combined_data.index.duplicated(keep='first')]  # Remove duplicates
    combined_data = combined_data.asfreq('H').interpolate(method='time')  # Resample to hourly frequency

# %%
from statsmodels.tsa.statespace.sarimax import SARIMAX

# Train-test split
train_data = combined_data['2022-01-01':'2024-12-31']

# Train a seasonal ARIMA (SARIMA) model
sarima_model = SARIMAX(
    train_data,
    order=(2, 1, 1),  # Example ARIMA order; adjust based on tuning
    seasonal_order=(1, 1, 1, 24),  # Seasonal order for daily patterns
    enforce_stationarity=False,
    enforce_invertibility=False
)
fitted_model = sarima_model.fit()

# Forecast for 2025
forecast_start = '2025-01-01 00:00:00'
forecast_end = '2025-12-31 23:00:00'
forecast = fitted_model.get_prediction(start=forecast_start, end=forecast_end, dynamic=False)
forecast_mean = forecast.predicted_mean
# Out:
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            6     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  5.88096D+00    |proj g|=  1.50182D-01
#  This problem is unconstrained.
# At iterate    5    f=  5.81700D+00    |proj g|=  4.54269D-01
#
# At iterate   10    f=  5.80755D+00    |proj g|=  1.24967D-01
#
# At iterate   15    f=  5.80712D+00    |proj g|=  9.60696D-03
#
# At iterate   20    f=  5.80443D+00    |proj g|=  2.01770D-01
#
# At iterate   25    f=  5.74208D+00    |proj g|=  1.78713D-01
#
# At iterate   30    f=  5.68949D+00    |proj g|=  1.32290D-01
#
# At iterate   35    f=  5.68030D+00    |proj g|=  2.17621D-02
#
# At iterate   40    f=  5.68025D+00    |proj g|=  6.85216D-05
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# ...

# %%
import pandas as pd
from statsmodels.tsa.statespace.sarimax import SARIMAX
from statsmodels.graphics.tsaplots import plot_acf, plot_pacf
import matplotlib.pyplot as plt

# Load datasets (update file paths as needed)
data_2021 = pd.read_csv('/Users/aashrithasankineni/Downloads/california_carbon_footprint/US-CAL-CISO_2021_hourly.csv')
data_2022 = pd.read_csv('/Users/aashrithasankineni/Downloads/california_carbon_footprint/US-CAL-CISO_2022_hourly.csv')
data_2023 = pd.read_csv('/Users/aashrithasankineni/Downloads/california_carbon_footprint/US-CAL-CISO_2023_hourly.csv')

# Combine datasets
data_combined = pd.concat([data_2021, data_2022, data_2023], ignore_index=True)

# Convert Datetime to pandas datetime and set as index
data_combined['Datetime (UTC)'] = pd.to_datetime(data_combined['Datetime (UTC)'])
data_combined.set_index('Datetime (UTC)', inplace=True)

# Explicitly set frequency for time index (hourly)
data_combined = data_combined.asfreq('h')

# Select the target column
carbon_intensity = data_combined['Carbon Intensity gCO₂eq/kWh (direct)']

# Plot ACF and PACF for non-seasonal components
plt.figure(figsize=(12, 6))
plt.subplot(121)
plot_acf(carbon_intensity.dropna(), lags=48, ax=plt.gca(), title="ACF (Autocorrelation)")
plt.subplot(122)
plot_pacf(carbon_intensity.dropna(), lags=48, ax=plt.gca(), title="PACF (Partial Autocorrelation)")
plt.tight_layout()
plt.show()

# Fit a SARIMA model with seasonal components
# Seasonal order (P, D, Q, S): Choose S=24 for hourly seasonality
print("Fitting SARIMA model...")
sarima_model = SARIMAX(
    carbon_intensity,
    order=(1, 1, 1),  # Non-seasonal (p, d, q)
    seasonal_order=(1, 1, 1, 24),  # Seasonal (P, D, Q, S)
    enforce_stationarity=False,
    enforce_invertibility=False
)
sarima_fit = sarima_model.fit(disp=False)

# Display model summary
print(sarima_fit.summary())

# Forecast for 2024 (8760 hours for a leap year)
forecast_steps = 8760  # Number of hours in 2024
future_dates = pd.date_range(start='2024-01-01 00:00:00', periods=forecast_steps, freq='h')
forecast_2024 = sarima_fit.forecast(steps=forecast_steps)

# Create a DataFrame for forecasted results
forecast_df = pd.DataFrame({'Datetime (UTC)': future_dates, 'Forecast': forecast_2024})
forecast_df.set_index('Datetime (UTC)', inplace=True)

# Save forecast to a CSV file
forecast_df.to_csv('/Users/aashrithasankineni/Downloads/forecast_2024_hourly_sarima.csv')

# Display a preview of the forecast
print("Hourly Forecast Preview (2024):")
print(forecast_df.head())
# Out:
# Fitting SARIMA model...
#                                         SARIMAX Results
# ...
# Dep. Variable:     Carbon Intensity gCO₂eq/kWh (direct)   No. Observations:                26280
# Model:                   SARIMAX(1, 1, 1)x(1, 1, 1, 24)   Log Likelihood              -85432.764
# Date:                                  Fri, 29 Nov 2024   AIC                         170875.528
# Time:                                          15:00:36   BIC                         170916.401
# Sample:                                      01-01-2021   HQIC                        170888.727
#                                            - 12-31-2023
# Covariance Type:                                    opg
# ...
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.L1         -0.0117      0.015     -0.793      0.428      -0.041       0.017
# ...

# %%
import plotly.graph_objects as go

# Create a dynamic graph using Plotly
fig = go.Figure()

# Add hourly forecast to the graph
fig.add_trace(go.Scatter(
    x=forecast_df.index,
    y=forecast_df['Forecast'],
    mode='lines',
    name='Hourly Forecast',
    line=dict(color='blue')
))

# Customize layout
fig.update_layout(
    title='Hourly Carbon Intensity Forecast for 2024',
    xaxis_title='Datetime (UTC)',
    yaxis_title='Carbon Intensity (gCO₂eq/kWh)',
    template='plotly_dark',
    legend=dict(x=0, y=1),
)

# Show the graph
fig.show()

# %%
import pandas as pd
from statsmodels.tsa.arima.model import ARIMA

# File paths for 2022, 2023, and 2024 data (update paths as necessary)
files = [
    '/Users/aashrithasankineni/Downloads/california_electricity_prices/caiso_lmp_rt_5min_interfaces_2022Q1.csv',
    '/Users/aashrithasankineni/Downloads/california_electricity_prices/caiso_lmp_rt_5min_interfaces_2022Q2.csv',
    '/Users/aashrithasankineni/Downloads/california_electricity_prices/caiso_lmp_rt_5min_interfaces_2022Q3.csv',
    '/Users/aashrithasankineni/Downloads/california_electricity_prices/caiso_lmp_rt_5min_interfaces_2022Q4.csv',
    '/Users/aashrithasankineni/Downloads/california_electricity_prices/caiso_lmp_rt_5min_interfaces_2023Q1.csv',
    '/Users/aashrithasankineni/Downloads/california_electricity_prices/caiso_lmp_rt_5min_interfaces_2023Q2.csv',
    '/Users/aashrithasankineni/Downloads/california_electricity_prices/caiso_lmp_rt_5min_interfaces_2023Q3.csv',
    '/Users/aashrithasankineni/Downloads/california_electricity_prices/caiso_lmp_rt_5min_interfaces_2024Q1.csv',
    '/Users/aashrithasankineni/Downloads/california_electricity_prices/caiso_lmp_rt_5min_interfaces_2024Q2.csv',
    '/Users/aashrithasankineni/Downloads/california_electricity_prices/caiso_lmp_rt_5min_interfaces_2024Q3.csv',
    '/Users/aashrithasankineni/Downloads/california_electricity_prices/caiso_lmp_rt_5min_interfaces_2024Q4.csv'
]

# Combine data from all files
data_combined = pd.concat([pd.read_csv(file, skiprows=3) for file in files], ignore_index=True)

# Parse timestamps and set as index
data_combined['Datetime (UTC)'] = pd.to_datetime(data_combined['UTC Timestamp (Interval Ending)'])
data_combined.set_index('Datetime (UTC)', inplace=True)

# Select the relevant electricity price column (replace with correct column name)
# Assuming 'Price' is the column of interest for electricity prices
electricity_prices = data_combined['PALOVRDE_ASR-APND LMP']  # Replace with actual column name

# Resample data to hourly averages
hourly_prices = electricity_prices.resample('H').mean()

# Fit the ARIMA model (adjust order if necessary)
print("Fitting ARIMA model...")
arima_model = ARIMA(hourly_prices, order=(1, 1, 1))  # Adjust (p, d, q) based on analysis
arima_fit = arima_model.fit()

# Forecast electricity prices for 2025 (8760 hours)
forecast_steps = 8760  # Number of hours in 2025
future_dates = pd.date_range(start='2025-01-01 00:00:00', periods=forecast_steps, freq='H')
forecast_2025 = arima_fit.forecast(steps=forecast_steps)

# Create a DataFrame for forecasted results
forecast_df = pd.DataFrame({'Datetime (UTC)': future_dates, 'Forecasted Price': forecast_2025})
forecast_df.set_index('Datetime (UTC)', inplace=True)

# Save forecast to a CSV file
forecast_df.to_csv('/Users/aashrithasankineni/Downloads/california_electricity_prices/forecasted_electricity_prices_2025.csv')

# Display a preview of the forecast
print("Hourly Forecast Preview (2025):")
print(forecast_df.head())
# Out:
# Fitting ARIMA model...
# Hourly Forecast Preview (2025):
#                      Forecasted Price
# Datetime (UTC)
# 2025-01-01 00:00:00         13.948001
# 2025-01-01 01:00:00         21.031757
# 2025-01-01 02:00:00         24.103508
# 2025-01-01 03:00:00         25.435521
# 2025-01-01 04:00:00         26.013125

# %%
# Aggregate forecast to daily averages
daily_forecast = forecast_df.resample('D').mean()
daily_forecast.to_csv('/Users/aashrithasankineni/Downloads/california_electricity_prices/forecasted_electricity_prices_2025_daily.csv')

# Aggregate forecast to monthly averages
monthly_forecast = forecast_df.resample('M').mean()
monthly_forecast.to_csv('/Users/aashrithasankineni/Downloads/california_electricity_prices/forecasted_electricity_prices_2025_monthly.csv')

# Hourly forecast is already saved; no further aggregation is needed for hourly.

# Display previews of all forecasts
print("Hourly Forecast Preview (2025):")
print(forecast_df.head())
print("\nDaily Forecast Preview (2025):")
print(daily_forecast.head())
print("\nMonthly Forecast Preview (2025):")
print(monthly_forecast.head())
# Out:
# Hourly Forecast Preview (2025):
#                      Forecasted Price
# Datetime (UTC)
# 2025-01-01 00:00:00         13.948001
# 2025-01-01 01:00:00         21.031757
# 2025-01-01 02:00:00         24.103508
# 2025-01-01 03:00:00         25.435521
# 2025-01-01 04:00:00         26.013125
#
# Daily Forecast Preview (2025):
#                 Forecasted Price
# Datetime (UTC)
# 2025-01-01             25.535217
# 2025-01-02             26.455362
# 2025-01-03             26.455362
# 2025-01-04             26.455362
# 2025-01-05             26.455362
#
# Monthly Forecast Preview (2025):
#                 Forecasted Price
# Datetime (UTC)
# 2025-01-31             26.425680
# 2025-02-28             26.455362
# 2025-03-31             26.455362
# 2025-04-30             26.455362
# 2025-05-31             26.455362

# %%
import pandas as pd
from statsmodels.tsa.statespace.sarimax import SARIMAX

# File paths for 2022, 2023, and 2024 data
files = [
    '/Users/aashrithasankineni/Downloads/california_electricity_prices/caiso_lmp_rt_5min_interfaces_2022Q1.csv',
    '/Users/aashrithasankineni/Downloads/california_electricity_prices/caiso_lmp_rt_5min_interfaces_2022Q2.csv',
    '/Users/aashrithasankineni/Downloads/california_electricity_prices/caiso_lmp_rt_5min_interfaces_2022Q3.csv',
    '/Users/aashrithasankineni/Downloads/california_electricity_prices/caiso_lmp_rt_5min_interfaces_2022Q4.csv',
    '/Users/aashrithasankineni/Downloads/california_electricity_prices/caiso_lmp_rt_5min_interfaces_2023Q1.csv',
    '/Users/aashrithasankineni/Downloads/california_electricity_prices/caiso_lmp_rt_5min_interfaces_2023Q2.csv',
    '/Users/aashrithasankineni/Downloads/california_electricity_prices/caiso_lmp_rt_5min_interfaces_2023Q3.csv',
    '/Users/aashrithasankineni/Downloads/california_electricity_prices/caiso_lmp_rt_5min_interfaces_2024Q1.csv',
    '/Users/aashrithasankineni/Downloads/california_electricity_prices/caiso_lmp_rt_5min_interfaces_2024Q2.csv',
    '/Users/aashrithasankineni/Downloads/california_electricity_prices/caiso_lmp_rt_5min_interfaces_2024Q3.csv',
    '/Users/aashrithasankineni/Downloads/california_electricity_prices/caiso_lmp_rt_5min_interfaces_2024Q4.csv'
]

# Combine all data
data_combined = pd.concat([pd.read_csv(file, skiprows=3) for file in files], ignore_index=True)

# Parse timestamps and set as index
data_combined['Datetime (UTC)'] = pd.to_datetime(data_combined['UTC Timestamp (Interval Ending)'])
data_combined.set_index('Datetime (UTC)', inplace=True)

# Select relevant electricity price column
electricity_prices = data_combined['PALOVRDE_ASR-APND LMP']  # Replace with the correct column name

# Resample to hourly averages
hourly_prices = electricity_prices.resample('H').mean()

# Fit the SARIMA model with seasonality (daily cycle)
seasonal_order = (1, 1, 1, 24)  # Seasonal parameters
sarima_model = SARIMAX(
    hourly_prices,  # Historical data
    order=(1, 1, 1),  # Non-seasonal ARIMA parameters
    seasonal_order=seasonal_order,  # Seasonal parameters
    enforce_stationarity=False,
    enforce_invertibility=False
)
sarima_fit = sarima_model.fit(disp=False)

# Display model summary
print("SARIMA Model Training Complete.")
print(sarima_fit.summary())

# Save the model for later use
sarima_fit.save('/Users/aashrithasankineni/Downloads/california_electricity_prices/sarima_model_2022_2024.pkl')
# Out:
# /var/folders/v8/hd7794fx5371lx6nxszm2j7w0000gn/T/ipykernel_4761/1144430110.py:30: FutureWarning: 'H' is deprecated and will be removed in a future version, please use 'h' instead.
#   hourly_prices = electricity_prices.resample('H').mean()
# SARIMA Model Training Complete.
#                                      SARIMAX Results
# ...
# Dep. Variable:              PALOVRDE_ASR-APND LMP   No. Observations:                25047
# Model:             SARIMAX(1, 1, 1)x(1, 1, 1, 24)   Log Likelihood             -109089.039
# Date:                            Wed, 04 Dec 2024   AIC                         218188.078
# Time:                                    00:29:26   BIC                         218228.711
# Sample:                                01-01-2022   HQIC                        218201.230
#                                      - 11-09-2024
# Covariance Type:                              opg
# ...
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ...

# %%
from statsmodels.tsa.statespace.sarimax import SARIMAXResults

# Load the saved SARIMA model
sarima_fit = SARIMAXResults.load('/Users/aashrithasankineni/Downloads/california_electricity_prices/sarima_model_2022_2024.pkl')

# Forecast for 2025 (8760 hours)
forecast_steps = 8760  # Number of hours in 2025
future_dates = pd.date_range(start='2025-01-01 00:00:00', periods=forecast_steps, freq='H')
forecast_2025 = sarima_fit.forecast(steps=forecast_steps)

# Create a DataFrame for forecasted results
forecast_df = pd.DataFrame({'Datetime (UTC)': future_dates, 'SARIMA Forecasted Price': forecast_2025})
forecast_df.set_index('Datetime (UTC)', inplace=True)

# Save forecast to a CSV file
forecast_df.to_csv('/Users/aashrithasankineni/Downloads/california_electricity_prices/forecasted_electricity_prices_2025_sarima.csv')

# Preview the first few rows of the forecast
print(forecast_df.head())
# Out:
# /var/folders/v8/hd7794fx5371lx6nxszm2j7w0000gn/T/ipykernel_4761/2267533807.py:8: FutureWarning: 'H' is deprecated and will be removed in a future version, please use 'h' instead.
#   future_dates = pd.date_range(start='2025-01-01 00:00:00', periods=forecast_steps, freq='H')
#                      SARIMA Forecasted Price
# Datetime (UTC)
# 2025-01-01 00:00:00                12.229775
# 2025-01-01 01:00:00                37.321443
# 2025-01-01 02:00:00                41.371557
# 2025-01-01 03:00:00                34.623485
# 2025-01-01 04:00:00                31.721899

# %%
import plotly.graph_objects as go

# Hourly Forecast Plot
fig_hourly = go.Figure()
fig_hourly.add_trace(go.Scatter(
    x=forecast_df.index,
    y=forecast_df['SARIMA Forecasted Price'],
    mode='lines',
    name='Hourly Forecast'
))
fig_hourly.update_layout(
    title='Hourly Electricity Price Forecast for 2025 (SARIMA)',
    xaxis_title='Datetime (UTC)',
    yaxis_title='Electricity Price',
    template='plotly_dark',
    legend=dict(x=0, y=1)
)
fig_hourly.show()

# Daily Forecast Plot
daily_forecast = forecast_df.resample('D').mean()
fig_daily = go.Figure()
fig_daily.add_trace(go.Scatter(
    x=daily_forecast.index,
    y=daily_forecast['SARIMA Forecasted Price'],
    mode='lines',
    name='Daily Forecast',
    line=dict(color='orange')
))
fig_daily.update_layout(
    title='Daily Electricity Price Forecast for 2025 (SARIMA)',
    xaxis_title='Date',
    yaxis_title='Average Electricity Price',
    template='plotly_dark',
    legend=dict(x=0, y=1)
)
fig_daily.show()

# Monthly Forecast Plot
monthly_forecast = forecast_df.resample('M').mean()
fig_monthly = go.Figure()
fig_monthly.add_trace(go.Scatter(
    x=monthly_forecast.index,
    y=monthly_forecast['SARIMA Forecasted Price'],
    mode='lines',
    name='Monthly Forecast',
    line=dict(color='green')
))
fig_monthly.update_layout(
    title='Monthly Electricity Price Forecast for 2025 (SARIMA)',
    xaxis_title='Month',
    yaxis_title='Average Electricity Price',
    template='plotly_dark',
    legend=dict(x=0, y=1)
)
fig_monthly.show()
# Out:
# /var/folders/v8/hd7794fx5371lx6nxszm2j7w0000gn/T/ipykernel_4761/338207618.py:40: FutureWarning:
#
# 'M' is deprecated and will be removed in a future version, please use 'ME' instead.

# %%
import pandas as pd
from statsmodels.tsa.statespace.sarimax import SARIMAX

# File paths for 2021, 2022, and 2023 data
files = [
    '/Users/aashrithasankineni/Downloads/california_electricity_prices/caiso_lmp_rt_5min_interfaces_2021Q1.csv',
    '/Users/aashrithasankineni/Downloads/california_electricity_prices/caiso_lmp_rt_5min_interfaces_2021Q2.csv',
    '/Users/aashrithasankineni/Downloads/california_electricity_prices/caiso_lmp_rt_5min_interfaces_2021Q3.csv',
    '/Users/aashrithasankineni/Downloads/california_electricity_prices/caiso_lmp_rt_5min_interfaces_2021Q4.csv',
    '/Users/aashrithasankineni/Downloads/california_electricity_prices/caiso_lmp_rt_5min_interfaces_2022Q1.csv',
    '/Users/aashrithasankineni/Downloads/california_electricity_prices/caiso_lmp_rt_5min_interfaces_2022Q2.csv',
    '/Users/aashrithasankineni/Downloads/california_electricity_prices/caiso_lmp_rt_5min_interfaces_2022Q3.csv',
    '/Users/aashrithasankineni/Downloads/california_electricity_prices/caiso_lmp_rt_5min_interfaces_2022Q4.csv',
    '/Users/aashrithasankineni/Downloads/california_electricity_prices/caiso_lmp_rt_5min_interfaces_2023Q1.csv',
    '/Users/aashrithasankineni/Downloads/california_electricity_prices/caiso_lmp_rt_5min_interfaces_2023Q2.csv',
    '/Users/aashrithasankineni/Downloads/california_electricity_prices/caiso_lmp_rt_5min_interfaces_2023Q3.csv'
]

# Combine all data
data_combined = pd.concat([pd.read_csv(file, skiprows=3) for file in files], ignore_index=True)

# Parse timestamps and set as index
data_combined['Datetime (UTC)'] = pd.to_datetime(data_combined['UTC Timestamp (Interval Ending)'])
data_combined.set_index('Datetime (UTC)', inplace=True)

# Select relevant electricity price column
electricity_prices = data_combined['PALOVRDE_ASR-APND LMP']  # Replace with the correct column name

# Resample to hourly averages
hourly_prices = electricity_prices.resample('H').mean()

# Fit the SARIMA model with seasonality (daily cycle)
seasonal_order = (1, 1, 1, 24)  # Seasonal parameters
sarima_model = SARIMAX(
    hourly_prices,  # Historical data
    order=(1, 1, 1),  # Non-seasonal ARIMA parameters
    seasonal_order=seasonal_order,  # Seasonal parameters
    enforce_stationarity=False,
    enforce_invertibility=False
)
sarima_fit = sarima_model.fit(disp=False)

# Display model summary
print("SARIMA Model Training Complete.")
print(sarima_fit.summary())

# Save the model for later use
model_path = '/Users/aashrithasankineni/Downloads/california_electricity_prices/sarima_model_2021_2023.pkl'
sarima_fit.save(model_path)

# Predict 2024 electricity prices
forecast_steps = 365 * 24  # Predict for one year (2024) in hourly steps
forecast = sarima_fit.get_forecast(steps=forecast_steps)
forecast_mean = forecast.predicted_mean
forecast_ci = forecast.conf_int()

# Save the forecast results
forecast_df = pd.DataFrame({
    'Forecast': forecast_mean,
    'Lower_CI': forecast_ci.iloc[:, 0],
    'Upper_CI': forecast_ci.iloc[:, 1]
})
forecast_df.to_csv('/Users/aashrithasankineni/Downloads/california_electricity_prices/forecast_2024.csv')

print("Forecast for 2024 saved to: forecast_2024.csv")
# Out:
# /var/folders/v8/hd7794fx5371lx6nxszm2j7w0000gn/T/ipykernel_2968/3042963244.py:30: FutureWarning: 'H' is deprecated and will be removed in a future version, please use 'h' instead.
#   hourly_prices = electricity_prices.resample('H').mean()
# SARIMA Model Training Complete.
#                                      SARIMAX Results
# ...
# Dep. Variable:              PALOVRDE_ASR-APND LMP   No. Observations:                24072
# Model:             SARIMAX(1, 1, 1)x(1, 1, 1, 24)   Log Likelihood             -120469.789
# Date:                            Tue, 03 Dec 2024   AIC                         240949.578
# Time:                                    20:13:25   BIC                         240990.011
# Sample:                                01-01-2021   HQIC                        240962.690
#                                      - 10-01-2023
# Covariance Type:                              opg
# ...
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ...

# %%
import pandas as pd
from sklearn.metrics import mean_absolute_error, mean_squared_error
import numpy as np

def calculate_metrics(predicted_file, actual_files, actual_column):
    # Load forecast data
    try:
        forecast_data = pd.read_csv(predicted_file)
        forecast_data['Unnamed: 0'] = pd.to_datetime(forecast_data['Unnamed: 0'])
    except Exception as e:
        print(f"Error loading forecast file: {e}")
        return
    
    # Load actual data and combine into a single DataFrame
    try:
        actual_dfs = [pd.read_csv(file, skiprows=3) for file in actual_files]
        actual_data = pd.concat(actual_dfs, ignore_index=True)
        actual_data['UTC Timestamp (Interval Ending)'] = pd.to_datetime(
            actual_data['UTC Timestamp (Interval Ending)']
        )
    except Exception as e:
        print(f"Error loading actual files: {e}")
        return
    
    # Merge forecast and actual data on timestamps
    try:
        merged_data = pd.merge(
            forecast_data,
            actual_data,
            left_on='Unnamed: 0',
            right_on='UTC Timestamp (Interval Ending)',
            how='inner'
        )
    except Exception as e:
        print(f"Error merging data: {e}")
        return

    # Extract predicted and actual values
    predicted_values = merged_data['Forecast']
    actual_values = merged_data[actual_column]

    # Calculate metrics
    mae = mean_absolute_error(actual_values, predicted_values)
    mse = mean_squared_error(actual_values, predicted_values)
    rmse = np.sqrt(mse)

    return mae, mse, rmse

# Paths
directory = '/Users/aashrithasankineni/Downloads/california_electricity_prices/'
predicted_file = f'{directory}forecast_2024.csv'
actual_files = [
    f'{directory}caiso_lmp_rt_5min_interfaces_2024Q1.csv',
    f'{directory}caiso_lmp_rt_5min_interfaces_2024Q2.csv',
    f'{directory}caiso_lmp_rt_5min_interfaces_2024Q3.csv',
    f'{directory}caiso_lmp_rt_5min_interfaces_2024Q4.csv'
]
actual_column = 'PALOVRDE_ASR-APND LMP'

# Compute metrics
metrics = calculate_metrics(predicted_file, actual_files, actual_column)
if metrics:
    mae, mse, rmse = metrics
    print(f"MAE: {mae}")
    print(f"MSE: {mse}")
    print(f"RMSE: {rmse}")
# Out:
# MAE: 79.53030518951084
# MSE: 8866.060697795423
# RMSE: 94.15976156403235

# %%
import pandas as pd
import matplotlib.pyplot as plt

# File paths for the selected years
files_selected_years = [
    '/Users/aashrithasankineni/Downloads/california_electricity_prices/caiso_lmp_rt_5min_interfaces_2021Q1.csv',
    '/Users/aashrithasankineni/Downloads/california_electricity_prices/caiso_lmp_rt_5min_interfaces_2021Q2.csv',
    '/Users/aashrithasankineni/Downloads/california_electricity_prices/caiso_lmp_rt_5min_interfaces_2021Q3.csv',
    '/Users/aashrithasankineni/Downloads/california_electricity_prices/caiso_lmp_rt_5min_interfaces_2021Q4.csv',
    '/Users/aashrithasankineni/Downloads/california_electricity_prices/caiso_lmp_rt_5min_interfaces_2022Q1.csv',
    '/Users/aashrithasankineni/Downloads/california_electricity_prices/caiso_lmp_rt_5min_interfaces_2022Q2.csv',
    '/Users/aashrithasankineni/Downloads/california_electricity_prices/caiso_lmp_rt_5min_interfaces_2022Q3.csv',
    '/Users/aashrithasankineni/Downloads/california_electricity_prices/caiso_lmp_rt_5min_interfaces_2022Q4.csv',
    '/Users/aashrithasankineni/Downloads/california_electricity_prices/caiso_lmp_rt_5min_interfaces_2023Q1.csv',
    '/Users/aashrithasankineni/Downloads/california_electricity_prices/caiso_lmp_rt_5min_interfaces_2023Q2.csv',
    '/Users/aashrithasankineni/Downloads/california_electricity_prices/caiso_lmp_rt_5min_interfaces_2023Q3.csv',
    '/Users/aashrithasankineni/Downloads/california_electricity_prices/caiso_lmp_rt_5min_interfaces_2024Q1.csv',
    '/Users/aashrithasankineni/Downloads/california_electricity_prices/caiso_lmp_rt_5min_interfaces_2024Q2.csv',
    '/Users/aashrithasankineni/Downloads/california_electricity_prices/caiso_lmp_rt_5min_interfaces_2024Q3.csv',
    '/Users/aashrithasankineni/Downloads/california_electricity_prices/caiso_lmp_rt_5min_interfaces_2024Q4.csv'
]

# Combine all files into one DataFrame
data_selected_years = pd.concat([pd.read_csv(file, skiprows=3) for file in files_selected_years], ignore_index=True)

# Convert timestamp column to datetime and set as index
data_selected_years['UTC Timestamp (Interval Ending)'] = pd.to_datetime(data_selected_years['UTC Timestamp (Interval Ending)'])
data_selected_years.set_index('UTC Timestamp (Interval Ending)', inplace=True)

# Specify the relevant price column
price_column = 'PALOVRDE_ASR-APND LMP'

# Add Year and Month columns for grouping
data_selected_years['Year'] = data_selected_years.index.year
data_selected_years['Month'] = data_selected_years.index.month

# Calculate monthly averages for the selected years
monthly_avg_selected_years = data_selected_years.groupby(['Year', 'Month'])[price_column].mean().reset_index()
monthly_avg_selected_years.rename(columns={price_column: 'Average Electricity Price'}, inplace=True)

# Pivot the data for plotting
monthly_avg_pivot = monthly_avg_selected_years.pivot(index='Month', columns='Year', values='Average Electricity Price')

# Plot the data
plt.figure(figsize=(16, 8))
month_labels = ['Jan', 'Feb', 'Mar', 'Apr', 'May', 'Jun', 'Jul', 'Aug', 'Sep', 'Oct', 'Nov', 'Dec']
for year in monthly_avg_pivot.columns:
    plt.plot(
        monthly_avg_pivot.index,
        monthly_avg_pivot[year],
        marker='o',
        label=f'{int(year)}',
        linewidth=2
    )

# Customize the plot
plt.title('Monthly Average Electricity Prices (2021-2024) - California', fontsize=18)
plt.xlabel('Month', fontsize=14)
plt.ylabel('Average Electricity Price ($/MWh)', fontsize=14)
plt.xticks(range(1, 13), month_labels, fontsize=12)
plt.legend(fontsize=12, loc='upper right')
plt.grid(alpha=0.6)
plt.tight_layout()
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Load the datasets from the specified paths
data_2021 = pd.read_csv('/Users/aashrithasankineni/Downloads/california_carbon_footprint/US-CAL-CISO_2021_hourly.csv')
data_2022 = pd.read_csv('/Users/aashrithasankineni/Downloads/california_carbon_footprint/US-CAL-CISO_2022_hourly.csv')
data_2023 = pd.read_csv('/Users/aashrithasankineni/Downloads/california_carbon_footprint/US-CAL-CISO_2023_hourly.csv')

# Combine the datasets for all years
data_combined = pd.concat([data_2021, data_2022, data_2023], ignore_index=True)

# Convert Datetime column to datetime format
data_combined['Datetime (UTC)'] = pd.to_datetime(data_combined['Datetime (UTC)'])

# Extract Year and Month for grouping
data_combined['Year'] = data_combined['Datetime (UTC)'].dt.year
data_combined['Month'] = data_combined['Datetime (UTC)'].dt.month

# Select numeric columns
numeric_columns = [
    'Carbon Intensity gCO₂eq/kWh (direct)',
    'Low Carbon Percentage',
    'Renewable Percentage',
]

# Group by Year and Month, and calculate the mean
monthly_avg = data_combined.groupby(['Year', 'Month'])[numeric_columns].mean().reset_index()

# Pivot the data for plotting
pivoted_data = monthly_avg.pivot(index='Month', columns='Year', values='Carbon Intensity gCO₂eq/kWh (direct)')

# Plot the Carbon Intensity (Direct) trends for each year
plt.figure(figsize=(16, 8))
month_labels = ['Jan', 'Feb', 'Mar', 'Apr', 'May', 'Jun', 'Jul', 'Aug', 'Sep', 'Oct', 'Nov', 'Dec']
for year in pivoted_data.columns:
    plt.plot(
        pivoted_data.index,
        pivoted_data[year],
        marker='o',
        label=f'{int(year)}',
        linewidth=2
    )

# Customize the plot
plt.title('Monthly Average Carbon Intensity (Direct) - California (2021-2023)', fontsize=18)
plt.xlabel('Month', fontsize=14)
plt.ylabel('Carbon Intensity (gCO₂eq/kWh)', fontsize=14)
plt.xticks(range(1, 13), month_labels, fontsize=12)
plt.legend(fontsize=12, loc='upper right')
plt.grid(alpha=0.6)
plt.tight_layout()
plt.show()

# Plot Renewable and Low Carbon Percentage for each year
plt.figure(figsize=(16, 8))
for col in ['Low Carbon Percentage', 'Renewable Percentage']:
    pivoted_data = monthly_avg.pivot(index='Month', columns='Year', values=col)
    for year in pivoted_data.columns:
        plt.plot(
            pivoted_data.index,
            pivoted_data[year],
            marker='o',
            label=f'{col} ({int(year)})',
            linewidth=2
        )

# Customize the plot
plt.title('Monthly Low Carbon and Renewable Energy Trends - California (2021-2023)', fontsize=18)
plt.xlabel('Month', fontsize=14)
plt.ylabel('Percentage (%)', fontsize=14)
plt.xticks(range(1, 13), month_labels, fontsize=12)
plt.legend(fontsize=12, loc='upper right', ncol=2)
plt.grid(alpha=0.6)
plt.tight_layout()
plt.show()
